# %% [markdown]
# YOLO implementation to better understand its functionality also get an idea on how the dataset structure looks like

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
# !unzip "/content/train_data.zip" -d "/content/"
# Out:
# Archive:  /content/train_data.zip
#    creating: /content/train_data/images/
#    creating: /content/train_data/images/train/
#   inflating: /content/train_data/images/train/OIP (21).jpg
#   inflating: /content/train_data/images/train/OIP (22).jpg
#   inflating: /content/train_data/images/train/OIP (23).jpg
#   inflating: /content/train_data/images/train/OIP (24).jpg
#   inflating: /content/train_data/images/train/OIP (25).jpg
#   inflating: /content/train_data/images/train/OIP (26).jpg
#   inflating: /content/train_data/images/train/OIP (27).jpg
#   inflating: /content/train_data/images/train/OIP (28).jpg
#   inflating: /content/train_data/images/train/OIP (29).jpg
#   inflating: /content/train_data/images/train/OIP (30).jpg
#   inflating: /content/train_data/images/train/OIP (31).jpg
#   inflating: /content/train_data/images/train/OIP (32).jpg
#   inflating: /content/train_data/images/train/OIP (33).jpg
#   inflating: /content/train_data/images/train/OIP (34).jpg
# ...

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 2 --epochs 20 --data new_project.yaml --weights yolov5s.pt --cache
# Out:
# 2023-12-11 20:17:44.213679: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 20:17:44.213736: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 20:17:44.213773: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
